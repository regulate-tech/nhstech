# %% [markdown]
# # 2. Add other relevant data: EPR suppliers and trust populations
#
# This notebook joins our tidy ERIC data with other relevant datasets: EPR suppliers, and trust catchment populations.
#
# Richard has obtained data on the primary EPR (electronic patient record) supplier to each NHS primary trust, as of January 2024; and also on trust catchment populations. This notebook does some exploratory analysis on those datasets, and then joins them to the ERIC data.
#
# Observations on the EPR suppliers data:
#
#
# - There are 209 trusts of which 135 are acute, 10 ambulance, 18 mental health, 13 community, and 33 combined mental health & community.
# - These trusts between them use 24 different EPR suppliers; the suppliers are mostly different depending on the type of trust.
# - In acute trusts, Oracle Cerner is the most widely (and only) used by acute trusts, and surprisingly 20 acute trusts don't have an EPR as of Jan 2024.
# - Mental health and community trusts all have EPRs, and are dominated by TPP and The Access Group.
# - The market is fairly concentrated in these big suppliers, but still there are quite a few small suppliers, across all types of trust.
# - This data also tells us trust type, and includes only active trusts (and seems to be a more reliable source of active status than the NHS ODS data)

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Join with EPR data
#
# First quickly import and explore the raw EPR data, to get a sense of what we're dealing with.

# %%
df_foi = pd.read_excel("./data/source/requests/secondary_trusts_primary_epr_suppliers_20240101.xlsx")
df_foi['Trust Type (Primary)'] = df_foi['Trust Type (Primary)'].str.strip() # Get rid of rogue whitespace.
df_foi.head()
# Out:
# /Users/anna/.pyenv/versions/3.11.5/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   Organisation Code  \
# 0               RCF
# 1               RBS
# 2               RTK
# 3               RVN
# 4               RF4
#
#                                                      Organisation  \
# 0                                   AIREDALE NHS FOUNDATION TRUST
# 1                       ALDER HEY CHILDREN'S NHS FOUNDATION TRUST
# 2           ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION TRUST
# 3          AVON AND WILTSHIRE MENTAL HEALTH PARTNERSHIP NHS TRUST
# 4  BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSPITALS NHS TRUST
#
#                      Trust Type (Primary)     Supplier (Primary EPR)
# 0                                   Acute                        TPP
# 1                                   Acute     Meditech Group Limited
# 2                                   Acute  Oracle Cerner Corporation
# 3  Mental Health and Community (Combined)           The Access Group
# 4                                   Acute    System C Healthcare Ltd

# %%
print('There are', len(df_foi), 'trusts, of the following types:')
print(df_foi.groupby("Trust Type (Primary)").size().reset_index(name='count').sort_values(['count'], ascending=False).to_string(index=False))
print('using', df_foi['Supplier (Primary EPR)'].nunique(), 'different suppliers')
# Out:
# There are 209 trusts, of the following types:
#                   Trust Type (Primary)  count
#                                  Acute    135
# Mental Health and Community (Combined)     33
#                          Mental Health     18
#                              Community     13
#                              Ambulance     10
# using 24 different suppliers

# %%
df_foi.head()
# Out:
#   Organisation Code  \
# 0               RCF
# 1               RBS
# 2               RTK
# 3               RVN
# 4               RF4
#
#                                                      Organisation  \
# 0                                   AIREDALE NHS FOUNDATION TRUST
# 1                       ALDER HEY CHILDREN'S NHS FOUNDATION TRUST
# 2           ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION TRUST
# 3          AVON AND WILTSHIRE MENTAL HEALTH PARTNERSHIP NHS TRUST
# 4  BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSPITALS NHS TRUST
#
#                      Trust Type (Primary)     Supplier (Primary EPR)
# 0                                   Acute                        TPP
# 1                                   Acute     Meditech Group Limited
# 2                                   Acute  Oracle Cerner Corporation
# 3  Mental Health and Community (Combined)           The Access Group
# 4                                   Acute    System C Healthcare Ltd

# %% [markdown]
# Different types of trust seem to use quite different suppliers - explore by trust type and supplier.

# %%
grouped_by_trust = (df_foi.groupby(["Trust Type (Primary)", "Supplier (Primary EPR)"])
                   .size()
                   .reset_index(name='count')
                   .sort_values(['Trust Type (Primary)', 'count'], ascending=[True, False]))
print(grouped_by_trust.to_string(index=False))
# Out:
#                   Trust Type (Primary)              Supplier (Primary EPR)  count
#                                  Acute           Oracle Cerner Corporation     30
#                                  Acute No EPR -  in process of getting one     20
#                                  Acute             System C Healthcare Ltd     18
#                                  Acute    Generic or In House EPR Provider     15
#                                  Acute              Dedalus Healthcare Ltd     14
#                                  Acute               Altera Digital Health     10
#                                  Acute            Epic Systems Corporation      9
#                                  Acute              Meditech Group Limited      5
#                                  Acute            Nervecentre Software Ltd      3
#                                  Acute                            Alcidion      2
#                                  Acute                      IMS Maxims Ltd      2
#                                  Acute                          CGI UK Ltd      1
#                                  Acute       Cambio Healthcare Systems Ltd      1
#                                  Acute                         Fortrus Ltd      1
#                                  Acute                 Graphnet Health Ltd      1
#                                  Acute                        InterSystems      1
#                                  Acute                           QuadraMed      1
#                                  Acute                                 TPP      1
#                              Ambulance        Cleric Computer Services Ltd      4
#                              Ambulance     Medusa Medical Technologies Inc      2
#                              Ambulance                      Ortivus UK Ltd      2
#                              Ambulance              Dedalus Healthcare Ltd      1
#                              Ambulance    Generic or In House EPR Provider      1
#                              Community                                 TPP     10
#                              Community                    The Access Group      3
#                          Mental Health                    The Access Group      5
#                          Mental Health    Advanced Health and Care Limited      4
#                          Mental Health                                 TPP      4
#                          Mental Health                   Civica UK Limited      3
#                          Mental Health              Dedalus Healthcare Ltd      2
# Mental Health and Community (Combined)                    The Access Group     16
# Mental Health and Community (Combined)                                 TPP     12
# Mental Health and Community (Combined)    Advanced Health and Care Limited      3
# Mental Health and Community (Combined)                   Civica UK Limited      1
# Mental Health and Community (Combined)              Dedalus Healthcare Ltd      1

# %% [markdown]
# ### Now join the EPR and ERIC data
#
# Happily, this joins cleanly on organisational code.

# %%
df_eric = pd.read_csv("./data/output/trust_mrc_clean.csv")
len(df_eric)
# Out:
# 234

# %%
df_eric.head()
# Out:
#   trust_code  \
# 0        R0A
# 1        R0B
# 2        R0D
# 3        R1A
# 4        R1C
#
#                                                                                                 trust_name  \
# 0                                                               MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 1  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION TRUST, SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION TRUST
# 2                                                         UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST
# 3     WORCESTERSHIRE HEALTH AND CARE NHS TRUST, HEREFORDSHIRE AND WORCESTERSHIRE HEALTH AND CARE NHS TRUST
# 4                                                                                         SOLENT NHS TRUST
#
#    mrc_off_201718  mrc_off_201819  mrc_off_201920  mrc_off_202021  \
# 0        203096.0        145631.0        277200.0        458075.0
# 1             0.0             0.0        305675.0        474199.0
# 2             0.0             0.0             0.0        989106.0
# 3        107682.0        118345.0        128996.0        140606.0
# 4         71981.0         83204.0         66826.0         63516.0
#
#    mrc_off_202122  mrc_off_202223  mrc_off_202324  mrc_on_201718  \
# 0        438847.0        296103.0        524104.0      3612846.0
# 1        306977.0        309358.0        528858.0            0.0
# 2        477552.0        460039.0        227047.0            0.0
# 3        211261.0        221822.0        123636.0       155193.0
# 4         62072.0         66994.0         62480.0        53002.0
#
#    mrc_on_201819  mrc_on_201920  mrc_on_202021  mrc_on_202122  mrc_on_202223  \
# 0      2871339.0      3285737.0      3285787.0      4875116.0      5629069.0
# 1            0.0      1703707.0      1141689.0       687573.0       651088.0
# 2            0.0            0.0      1052080.0      1269710.0      1243808.0
# 3       169347.0       184588.0       201201.0       147636.0       155015.0
# 4        39584.0        61596.0        27673.0        41186.0        15703.0
#
#    mrc_on_202324 mrc_service_provision_201718 mrc_service_provision_201819  \
# 0      5557232.0                     Internal                     Internal
# 1      1154972.0                          NaN                          NaN
# 2      1318124.0                          NaN                          NaN
# 3       187229.0                       Hybrid                       Hybrid
# 4        31174.0                       Hybrid                       Hybrid
#
#   mrc_service_provision_201920 mrc_service_provision_202021  \
# 0                     Internal                     Internal
# 1                       Hybrid                       Hybrid
# 2                          NaN                       Hybrid
# 3                       Hybrid                     Internal
# 4                       Hybrid                       Hybrid
#
#   mrc_service_provision_202122 mrc_service_provision_202223  \
# 0                     Internal                     Internal
# 1                       Hybrid                       Hybrid
# 2                       Hybrid                       Hybrid
# 3                     Internal                     Internal
# 4                       Hybrid                       Hybrid
#
#   mrc_service_provision_202324 mrc_type_201718 mrc_type_201819  \
# 0                     Internal           Mixed        3. Mixed
# 1                       Hybrid             NaN             NaN
# 2                       Hybrid             NaN             NaN
# 3                       Hybrid           Mixed        3. Mixed
# 4                       Hybrid           Mixed        3. Mixed
#
#   mrc_type_201920 mrc_type_202021 mrc_type_202122 mrc_type_202223  \
# 0        3. Mixed        3. Mixed        3. Mixed        3. Mixed
# 1        3. Mixed        3. Mixed        3. Mixed        3. Mixed
# 2             NaN        3. Mixed        3. Mixed        3. Mixed
# 3        3. Mixed        3. Mixed        3. Mixed        3. Mixed
# 4        3. Mixed        3. Mixed        3. Mixed        3. Mixed
#
#   mrc_type_202324  mrc_total_201718  mrc_total_201819  mrc_total_201920  \
# 0        3. Mixed         3815942.0         3016970.0         3562937.0
# 1        3. Mixed               0.0               0.0         2009382.0
# 2        3. Mixed               0.0               0.0               0.0
# 3        3. Mixed          262875.0          287692.0          313584.0
# 4        3. Mixed          124983.0          122788.0          128422.0
#
#    mrc_total_202021  mrc_total_202122  mrc_total_202223  mrc_total_202324
# 0         3743862.0         5313963.0         5925172.0         6081336.0
# 1         1615888.0          994550.0          960446.0         1683830.0
# 2         2041186.0         1747262.0         1703847.0         1545171.0
# 3          341807.0          358897.0          376837.0          310865.0
# 4           91189.0          103258.0           82697.0           93654.0

# %%
df_joined = pd.merge(df_eric, df_foi, left_on="trust_code", right_on="Organisation Code", how="outer")
df_joined.columns
# Out:
# Index(['trust_code', 'trust_name', 'mrc_off_201718', 'mrc_off_201819',
#        'mrc_off_201920', 'mrc_off_202021', 'mrc_off_202122', 'mrc_off_202223',
#        'mrc_off_202324', 'mrc_on_201718', 'mrc_on_201819', 'mrc_on_201920',
#        'mrc_on_202021', 'mrc_on_202122', 'mrc_on_202223', 'mrc_on_202324',
#        'mrc_service_provision_201718', 'mrc_service_provision_201819',
#        'mrc_service_provision_201920', 'mrc_service_provision_202021',
#        'mrc_service_provision_202122', 'mrc_service_provision_202223',
#        'mrc_service_provision_202324', 'mrc_type_201718', 'mrc_type_201819',
#        'mrc_type_201920', 'mrc_type_202021', 'mrc_type_202122',
#        'mrc_type_202223', 'mrc_type_202324', 'mrc_total_201718',
#        'mrc_total_201819', 'mrc_total_201920', 'mrc_total_202021',
#        'mrc_total_202122', 'mrc_total_202223', 'mrc_total_202324',
#        'Organisation Code', 'Organisation', 'Trust Type (Primary)',
#        'Supplier (Primary EPR)'],
#       dtype='object')

# %% [markdown]
# ### Check for rows that didn't join cleanly
#
# Everything in the FOI data is in the ERIC data. But there are 23 'active' trusts in the ERIC data not in the FOI data - all with zero spending in 23/24.
#
# Debugging this, Wikipedia sugests that many of these are really ex-trusts ([example](https://en.wikipedia.org/wiki/Basildon_and_Thurrock_University_Hospitals_NHS_Foundation_Trust)) - NB they are in the ODS dataset as "active", so ODS status may not reflect reality.
#
# We will exclude these from any analysis of the current data.

# %%
print(len(df_joined[df_joined.trust_name.isnull()]), "trust codes in the FOI data that are not in the ERIC data")
print(len(df_joined[df_joined.Organisation.isnull()]), "trust codes in the ERIC data that are not in the FOI data:")
df_joined[df_joined.Organisation.isnull()].sort_values(by="trust_name")[['trust_code', 'trust_name', 'mrc_total_202324']]
# Out:
# 0 trust codes in the FOI data that are not in the ERIC data
# 25 trust codes in the ERIC data that are not in the FOI data:
#     trust_code  \
# 45         RDD
# 35         RC1
# 195        RXH
# 82         RJF
# 94         RLN
# 224        RYK
# 9          R1J
# 130        RR1
# 65         RGQ
# 208        RY1
# 125        RQ8
# 108        RNL
# 153        RTV
# 34         RBZ
# 167        RW6
# 43         RD3
# 142        RT3
# 124        RQ6
# 51         RE9
# 163        RVY
# 6          R1E
# 25         RBA
# 50         RDZ
# 13         RA3
# 14         RA4
#
#                                                                 trust_name  \
# 45         BASILDON AND THURROCK UNIVERSITY HOSPITALS NHS FOUNDATION TRUST
# 35                                              BEDFORD HOSPITAL NHS TRUST
# 195                     BRIGHTON AND SUSSEX UNIVERSITY HOSPITALS NHS TRUST
# 82                                   BURTON HOSPITALS NHS FOUNDATION TRUST
# 94                          CITY HOSPITALS SUNDERLAND NHS FOUNDATION TRUST
# 224                 DUDLEY AND WALSALL MENTAL HEALTH PARTNERSHIP NHS TRUST
# 9                                  GLOUCESTERSHIRE CARE SERVICES NHS TRUST
# 130                                  HEART OF ENGLAND NHS FOUNDATION TRUST
# 65                                              IPSWICH HOSPITAL NHS TRUST
# 208                                   LIVERPOOL COMMUNITY HEALTH NHS TRUST
# 125                                  MID ESSEX HOSPITAL SERVICES NHS TRUST
# 108                           NORTH CUMBRIA UNIVERSITY HOSPITALS NHS TRUST
# 153                    NORTH WEST BOROUGHS HEALTHCARE NHS FOUNDATION TRUST
# 34                                     NORTHERN DEVON HEALTHCARE NHS TRUST
# 167                                      PENNINE ACUTE HOSPITALS NHS TRUST
# 43                                     POOLE HOSPITAL NHS FOUNDATION TRUST
# 142                      ROYAL BROMPTON AND HAREFIELD NHS FOUNDATION TRUST
# 124          ROYAL LIVERPOOL AND BROADGREEN UNIVERSITY HOSPITALS NHS TRUST
# 51                                     SOUTH TYNESIDE NHS FOUNDATION TRUST
# 163                              SOUTHPORT AND ORMSKIRK HOSPITAL NHS TRUST
# 6                   STAFFORDSHIRE AND STOKE ON TRENT PARTNERSHIP NHS TRUST
# 25                               TAUNTON AND SOMERSET NHS FOUNDATION TRUST
# 50   THE ROYAL BOURNEMOUTH AND CHRISTCHURCH HOSPITALS NHS FOUNDATION TRUST
# 13                                            WESTON AREA HEALTH NHS TRUST
# 14                           YEOVIL DISTRICT HOSPITAL NHS FOUNDATION TRUST
#
#      mrc_total_202324
# 45                0.0
# 35                0.0
# 195               0.0
# 82                0.0
# 94                0.0
# 224               0.0
# 9                 0.0
# 130               0.0
# 65                0.0
# 208               0.0
# 125               0.0
# 108               0.0
# 153               0.0
# 34                0.0
# 167               0.0
# 43                0.0
# 142               0.0
# 124               0.0
# 51                0.0
# 163               0.0
# 6                 0.0
# 25                0.0
# 50                0.0
# 13                0.0
# 14                0.0

# %% [markdown]
# Add a utility column to flag whether the trust is in the FOI data, to make life easier.

# %%
df_joined['in_foi_data'] = ~df_joined.Organisation.isnull()
df_joined.head(2)
# Out:
#   trust_code  \
# 0        R0A
# 1        R0B
#
#                                                                                                 trust_name  \
# 0                                                               MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 1  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION TRUST, SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION TRUST
#
#    mrc_off_201718  mrc_off_201819  mrc_off_201920  mrc_off_202021  \
# 0        203096.0        145631.0        277200.0        458075.0
# 1             0.0             0.0        305675.0        474199.0
#
#    mrc_off_202122  mrc_off_202223  mrc_off_202324  mrc_on_201718  \
# 0        438847.0        296103.0        524104.0      3612846.0
# 1        306977.0        309358.0        528858.0            0.0
#
#    mrc_on_201819  mrc_on_201920  mrc_on_202021  mrc_on_202122  mrc_on_202223  \
# 0      2871339.0      3285737.0      3285787.0      4875116.0      5629069.0
# 1            0.0      1703707.0      1141689.0       687573.0       651088.0
#
#    mrc_on_202324 mrc_service_provision_201718 mrc_service_provision_201819  \
# 0      5557232.0                     Internal                     Internal
# 1      1154972.0                          NaN                          NaN
#
#   mrc_service_provision_201920 mrc_service_provision_202021  \
# 0                     Internal                     Internal
# 1                       Hybrid                       Hybrid
#
#   mrc_service_provision_202122 mrc_service_provision_202223  \
# 0                     Internal                     Internal
# 1                       Hybrid                       Hybrid
#
#   mrc_service_provision_202324 mrc_type_201718 mrc_type_201819  \
# 0                     Internal           Mixed        3. Mixed
# 1                       Hybrid             NaN             NaN
#
#   mrc_type_201920 mrc_type_202021 mrc_type_202122 mrc_type_202223  \
# 0        3. Mixed        3. Mixed        3. Mixed        3. Mixed
# 1        3. Mixed        3. Mixed        3. Mixed        3. Mixed
#
#   mrc_type_202324  mrc_total_201718  mrc_total_201819  mrc_total_201920  \
# 0        3. Mixed         3815942.0         3016970.0         3562937.0
# 1        3. Mixed               0.0               0.0         2009382.0
#
#    mrc_total_202021  mrc_total_202122  mrc_total_202223  mrc_total_202324  \
# 0         3743862.0         5313963.0         5925172.0         6081336.0
# 1         1615888.0          994550.0          960446.0         1683830.0
#
#   Organisation Code                                        Organisation  \
# 0               R0A          MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 1               R0B  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION TRUST
#
#   Trust Type (Primary)    Supplier (Primary EPR)  in_foi_data
# 0                Acute  Epic Systems Corporation         True
# 1                Acute    Meditech Group Limited         True

# %% [markdown]
# Tidy up column names.

# %%
df_joined.rename(columns={
    'Trust Type (Primary)': 'trust_type',
    'Supplier (Primary EPR)': 'trust_epr',
    'Organisation': 'current_name' # Use the name from the FOI data as the current main name.
}, inplace=True)
df_joined.drop('Organisation Code', axis=1, inplace=True) # Drop duplicate column.

# %% [markdown]
# ## Add trust population data
#
# We have [data on trust catchment populations](https://www.eastsussexjsna.org.uk/resources/nhs-acute-hospital-trust-catchment-populations/) - these are experimental statistics, based on modelled estimates from the Office for Health Improvement and Disparities.
#
# Add these to our data to help us normalise the spending by patient.

# %%
df_pop = pd.read_excel("./data/source/ohid/2022_trust_catchment_populations.xlsx")
df_pop.head()
df_pop.rename(columns={
    'All admissions': 'all_admissions_22',
    'Emergency admissions': 'emergency_admissions_22',
}, inplace=True)
df_pop.all_admissions_22.sum()
# Out:
# 56550138

# %%
df_all = pd.merge(df_joined, df_pop, left_on="trust_code", right_on="TrustCode", how="outer")
df_all.head()
len(df_all)
# Out:
# 234

# %% [markdown]
# Note that some trusts don't have population catchment data: these look like specialist trusts (eye, cancer, orthopaedic, children, women's etc).

# %%
df_all[(df_all.all_admissions_22.isnull()) & (df_all.trust_type == 'Acute')][['trust_name', 'trust_type', 'in_foi_data']]
# Out:
#                                                                                                   trust_name  \
# 20                                                             ROYAL NATIONAL ORTHOPAEDIC HOSPITAL NHS TRUST
# 30   LIVERPOOL HEART AND CHEST NHS FOUNDATION TRUST, LIVERPOOL HEART AND CHEST HOSPITAL NHS FOUNDATION TRUST
# 31                                                                  ALDER HEY CHILDRENS NHS FOUNDATION TRUST
# 33                                                                         THE CHRISTIE NHS FOUNDATION TRUST
# 40                                                                  SHEFFIELD CHILDRENS NHS FOUNDATION TRUST
# 54                                                          CLATTERBRIDGE CANCER CENTRE NHS FOUNDATION TRUST
# 55                                                                    LIVERPOOL WOMEN'S NHS FOUNDATION TRUST
# 56                                                                        WALTON CENTRE NHS FOUNDATION TRUST
# 62                                                              ROYAL PAPWORTH HOSPITAL NHS FOUNDATION TRUST
# 92                                     ROBERT JONES AND AGNES HUNT ORTHOPAEDIC HOSPITAL NHS FOUNDATION TRUST
# 115                                           GREAT ORMOND STREET HOSPITAL FOR CHILDREN NHS FOUNDATION TRUST
# 117                                                             MOORFIELDS EYE HOSPITAL NHS FOUNDATION TRUST
# 120                                                             QUEEN VICTORIA HOSPITAL NHS FOUNDATION TRUST
# 122                                                                   THE ROYAL MARSDEN NHS FOUNDATION TRUST
# 123                                                   BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATION TRUST
# 135                                                          ROYAL ORTHOPAEDIC HOSPITAL NHS FOUNDATION TRUST
#
#     trust_type  in_foi_data
# 20       Acute         True
# 30       Acute         True
# 31       Acute         True
# 33       Acute         True
# 40       Acute         True
# 54       Acute         True
# 55       Acute         True
# 56       Acute         True
# 62       Acute         True
# 92       Acute         True
# 115      Acute         True
# 117      Acute         True
# 120      Acute         True
# 122      Acute         True
# 123      Acute         True
# 135      Acute         True

# %% [markdown]
# Now we can calculate the spend per patient, which will help us compare trusts more meaningfully.

# %%
df_all['mrc_total_202324_perpatient'] = df_all.mrc_total_202324.astype(float) / df_all.all_admissions_22.astype(float)
df_all['mrc_total_202324_perpatient'] = df_all['mrc_total_202324_perpatient'].round(2)

# %% [markdown]
# ## Export all to CSV

# %%
# Remove unused columns.
df_all.drop(columns=['TrustCode', 'TrustName'], inplace=True)
# Rename other columns to be more readable. 
df_all.rename(columns={
    "current_name": "current_name_in_foi", 
    "trust_type": "trust_type_from_foi"
}, inplace=True)
df_all.sort_values(by="trust_name").to_csv('./data/output/trust_mrc_and_epr.csv', index=False)
